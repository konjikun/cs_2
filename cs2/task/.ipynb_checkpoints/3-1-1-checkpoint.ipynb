# %%
class Student:
    def __init__(self, id, familyname, firstname):
        self.student_id = id
        self.family_name = familyname
        self.first_name = firstname
    def __lt__(self, other):
        return self.student_id < other.student_id###

# %%
lst = [Student(112, 'Tanaka','Taro'), Student(110, 'Yamada', 'Hanako'),Student(231,'Inoue','Ken')]
lst2 =sorted(lst,a=func)

print(lst2[0].family_name, lst2[1].family_name, lst2[2].family_name)
# Out:
# Inoue Tanaka Yamada

# %%
def func(a):
    return a.family_name

# %%
import matplotlib.pyplot as plt
xs = [100,200,300,400,500,600,700,800,900,1000]
ys = [0, 1.53, 3.54, 6.44, 10.5, 13.6, 18.7, 24.6, 30.2, 37.7]
plt.plot(xs, ys, "o")
plt.xlabel("n")
plt.ylabel("time(ms)")
plt.title("Time of selection_sort(n)")
# Out:
# Text(0.5, 1.0, 'Time of selection_sort(n)')
